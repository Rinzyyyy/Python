# %%
from selenium import webdriver
import requests 
import time
import openpyxl
import jieba

# wb=openpyxl.Workbook()
# ws=wb.active

# ws["A1"]="活動名稱"
# ws["B1"]="按讚人數"
# ws["C1"]="日期"
# ws["D1"]="網址"

tech=5 #7頁
des=19 #13頁

tech_title=[]
des_title=[]


from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

driver=webdriver.Chrome("/Users/xuan/python/chromedriver.exe")

for p in range(0,7):
    
    res=driver.get("https://old.accupass.com/search/r/0/5/6/0/4/"+str(p)+"/20220101/20221231?q=%E5%B1%95%E8%A6%BD")
    
    print("-------",p,"---------")
    
    for i in range(2,14):

        time.sleep(2)
        
        try:
            #likes=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[3]/div/div/section/div[1]/div['+str(i)+']/div/div[3]/div/div[1]/span')
            title=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[3]/div/div/section/div[1]/div['+str(i)+']/div/div[2]/a/h3')
            #date=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[3]/div/div/section/div[1]/div['+str(i)+']/div/div[2]/p')
            #site=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[3]/div/div/section/div[1]/div['+str(i)+']/div/div[2]/a')

            a=title.text
            #b=likes.text[:-3]
            #c=date.text
            #d=site.get_attribute("ng-href")
            
            #tech_title.append(a)
            #des_title.append(a)
            

            #ws.append([a,b,c,d])
            #print(i)
            
        except:
            print("pass")
            pass
    
    #wb.save("設計展覽.xlsx")
    
    time.sleep(5)
    
driver.quit()

print("done")
# Out:
# /var/folders/d0/gstvjrv16_l_0pk52fjd4nrw0000gn/T/ipykernel_21234/4269296344.py:25: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("/Users/xuan/python/chromedriver.exe")
# ------- 0 ---------
# pass
# pass
# ------- 1 ---------
# ------- 2 ---------
# ------- 3 ---------
# ------- 4 ---------
# ------- 5 ---------
# ------- 6 ---------
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# pass
# done

# %%
#print(tech_title)
#print(des_title)

wb=openpyxl.Workbook()
ws=wb.active

ws["A1"]="關鍵字"
ws["B1"]="次數"


import jieba
import operator
import openpyxl

dic={}
lis=[]

for n in des_title :
    
    lis+=jieba.lcut(n)
    
# print(list)


for x in lis :    

    if x in dic:

        dic[x]+=1

    else :

        dic[x]=1
        
#print(dic)
        

sort=sorted(dic.items(),key=operator.itemgetter(1),reverse=True)

for s in sort :

    if len(s[0])>1:
        print(s[0],s[1])
        ws.append([s[0],s[1]])

wb.save("科技關鍵字.xlsx")
# Out:
# 2022 16
# 智慧 13
# 科技 13
# 數位 10
# 講座 10
# 宇宙 7
# 年度 7
# 活動 6
# 創新 6
# 111 6
# 北市 6
# 知識 6
# 學苑 6
# 學校 6
# 經濟 6
# 5G 5
# 體驗 5
# 計畫 5
# 發展 5
# 未來 4
# 表演 4
# 研討會 4
# 工作坊 4
# 論壇 4
# 解密 4
