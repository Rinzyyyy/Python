# %% [markdown]
# ### def apple():
#
#         a=3
#         b=4
#         c=a+b
#         print(c)
#
# print("hi")
# apple()
# print("exit")

# %%
def ss1(a) :
    
    b=4
    c=a+b
    print(c)

ss1(3)

# %%
def ss2(a, b) :
    
    c=a+b
    print(c)
    
ss2(3,4)

# %%
def ss3(a) :
    b=4
    c=a+b
    print("v")
    
ss3(3)

# %%
def ss2(a,b) :
    c=a+b
    return c

ss2(3,4)
#print(ss2(3,4))
# Out:
# 7

# %%
x=ss2(3,4)
print(x)

# %%
class her:
    
    def __init__(self , name ,isgood ) :
        self.name = name
        self.isgood = isgood
        
    def got_status(self,number) :
        
        print("her name is", self.name ,",she feels", str(self.isgood),number)

bye = her("bye", "good")

bye.got_status(10)

# %%
class person :
    
    def __init__(self, name, hp, attack) :
        self.name = name
        self.hp = hp
        self.attack = attack
        
    def attack_by_enemy(self) :
        self.hp -= 1
        
    def get_info(self) :
        print(self.name)
        print(self.hp)
        print(self.attack)
        
    def change_name(self, newname) :
        self.name = newname
    
chopper = person("peter",100,3)
miner = person("David", 10,200)

miner.attack_by_enemy()
miner.get_info()

print("*change name*")

miner.change_name("Jason")
miner.get_info()

# %%
class people :
    
    def __init__(self, name, hp, attack) :
        self.name = name
        self.hp = hp
        self.attack = attack
        
    def attack_by_life(self) :
        import random
        w=random.randint(1,10)
        print("隨機扣血",w)
        self.hp -= w
        
    def attack_by_person(self,p) :
         self.hp -= p.attack
        
    def get_info(self) :
        print("name",self.name)
        print("餘血",self.hp)
        print("攻擊力",self.attack)

        
one = people(input("Name  "),int(input("血量 :")),9)
two = people(input("Name  "),int(input("血量 :")),10)
one.attack_by_life()
one.get_info()

one.attack_by_person(two)
print("被攻擊後")
one.get_info()

# %%
import random
aa=random.randint(1,10)
print(aa)

# %%
class people :
    
    def __init__(self, name, hp, attack) :
        self.name = name
        self.hp = hp
        self.attack = attack
        
    def attack_by_life(self) :
        import random
        w=random.randint(1,10)
        print("隨機扣血",w)
        self.hp -= w
        
    def attack_by_person(self,p) :
         self.hp -= p.attack
        
    def get_info(self) :
        print("name",self.name)
        print("餘血",self.hp)
        print("攻擊力",self.attack)


class world :
    
            def __init__(self) :
            
                self.people=[]

            def append_people(self,p) :
                
                self.people.append (p)

            def war (self) :

                self.people[0].attack_by_person(self.people[1]) 
                for p in self.people :
                    p.get_info()
                    print("-----")

one = people(input("Name  "),int(input("血量 :")),9)
two = people(input("Name  "),int(input("血量 :")),10)
 
print("--start--")
w = world()
w.append_people(one)
w.append_people(two)
w.war()

# %%
class Person:
    def __init__(self, name, hp, attack):
        self.name = name
        self.hp = hp
        self.attack = attack
        
    def change_hp(self, hp):
        
        self.hp = hp
        
    def attack_by_person(self, p):
        self.change_hp(self.hp-p.attack)
        
    def healing(self):
        self.change_hp(self.hp+1)
        
    def change_name(self,n):
        self.name = n
        
    def get_info(self):
        print("-")
        print(self.name)
        print("Blood : ",self.hp)
        print("Attack : ",self.attack)
        print(" ")
        
class World:
    def __init__(self):
        self.people=[]
        
    def append_people(self,p):
        self.people.append(p)
        
    def war(self):
        import random
     
        n=0
        
        while n<3 :
            
            print("-----Round",n+1,"-----")
            
            
            v = random.randint(0,3)
            z = random.randint(0,3)
            
            if v != z :
                self.people[v].attack_by_person(self.people[z])

                nb = self.people[v].name
                na = self.people[z].name
                print(nb,"Attack by",na)

                self.people[v].get_info()
                
            else :
                
                if v<=3 :
                        v-1
                        self.people[v].attack_by_person(self.people[z])

                        nb = self.people[v].name
                        na = self.people[z].name
                        print(nb,"Attack by",na)

                        self.people[v].get_info()

                elif v>=0 :
                        v+1 
                        self.people[v].attack_by_person(self.people[z])

                        nb = self.people[v].name
                        na = self.people[z].name
                        print(nb,"Attack by",na)

                        self.people[v].get_info()
                

            n+=1


Chopper = Person("Chopper",100,20)
Miner = Person("Miner",100,20)
marksman =Person("射手",90,30)
mega =Person("法師",90,30)

world = World()
world.append_people(Chopper)
world.append_people(Miner)
world.append_people(marksman)
world.append_people(mega)
world.war()

# %%
import requests
resource=requests.get ("https://www.1111.com.tw/search/job?ks=大數據")

#print(resource)              #<Response [200]>為連線成功，<Response [404]>為連線失敗
#print(resource.text)       #顯示網頁資料內容HTML 
                                   #ctrl+F 搜尋關鍵字 
                                  # Hyper Text  Markup Language
        
        
from bs4 import BeautifulSoup
soup1=BeautifulSoup(resource.text)

#for job in soup1.find_all("h5",class_="card-title title_6") : #職缺名稱
        #print(job.text)

#print(len(soup1.find_all("div",class_="job_item_info"))) #職缺項目個數 可用在做while的停止判斷 (最小單位資料) 
#print(soup1.find_all("div",class_="job_item_info"))

from time import sleep
import openpyxl

wb=openpyxl.Workbook()
ws=wb.active
ws["A1"]="職缺名稱"
ws["B1"]="公司名稱"
ws["C1"]="職缺連結"
ws["D1"]="職缺地區"
ws["E1"]="薪資待遇"
ws["F1"]="給薪方式"
ws["G1"]="上限"
ws["H1"]="下限"

page=1

while page<3 : #在數值為空值時停止(超過頁數)
    
    print("正在讀取第",page,"頁")
    page+=1
    
    for info in soup1.find_all("div",class_="job_item_info") :
            
            a=info.h5.text
            b=info.h6.text
            c=info.a["href"]
            d=info.find("a",class_="job_item_detail_location mr-3 position-relative").text
            e=info.find("div",class_="job_item_detail_salary ml-3 font-weight-style digit_6").text
            
            print(e[:2])
            
            #篩選薪水內容
            salary=""
            for s in e :
                if s=="." or s=="萬" or s=="~" or s.isdigit() :
                    salary+=s
            
            if "~" in salary :
                low_salary=salary[ : salary.find('~') ]
                high_salary=salary[ salary.find('~')+1 : ] 
            else :
                low_salary=salary
                high_salary=salary
                
                
            def won(aa):
            
                if "萬" in aa :
                    aa=float(aa[:aa.find("萬")])*10000
                else :
                    aa=float(aa)
                
                return aa
                
            ww=won(low_salary)
            w2=won(high_salary)
            
                
            
            #f=e[:2]
            print(ww)   
            print(w2) 
            

            #ws.append([a,b,c,d,e,f,g,h])
            #wb.save("20221216.xlsx")
            

            resource=requests.get ("https://www.1111.com.tw/search/job?ks=大數據&page="+str(page))
            soup1=BeautifulSoup(resource.text)
            sleep(3)
    
print(done)
# Out:
# 正在讀取第 1 頁
# 月薪
# 32000.0
# 32000.0
# 月薪
# 30000.0
# 30000.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/d0/gstvjrv16_l_0pk52fjd4nrw0000gn/T/ipykernel_35555/3163571871.py in <module>
#      87             resource=requests.get ("https://www.1111.com.tw/search/job?ks=大數據&page="+str(page))
#      88             soup1=BeautifulSoup(resource.text)
# ---> 89             sleep(3)
#      90
#      91 print(done)
#
# KeyboardInterrupt:
